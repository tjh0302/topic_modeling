# %% [markdown]
# # Unsupervised Topic Modeling
#
# - Unsupervised modeling is partially built out in the section below and in topic_modeling_LDA.py
# - Need to add a section for supervised topic modeling (classification) with predefined topics.

# %% [markdown]
# ## Unsupervised Topic Modeling
#
# Uses Latent Dirichlet Allocation from the gensim package and the pyLDAvis package for intertopic distance visualizations.

# %% [markdown]
# ### Dependencies

# %%
pip install pyLDAvis
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 26.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 26.1 MB/s eta 0:00:00
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

import pyLDAvis.gensim

import pandas as pd
import re

import gensim
import nltk
from nltk.corpus import stopwords
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %% [markdown]
# ### Training data and supporting data

# %%
corpus_list = [
    "Energy efficiency reduces costs and emissions.",
    "Renewable energy supports a cleaner grid.",
    "Energy storage stabilizes power supply.",
    "Smart grids optimize energy distribution.",
    "Energy audits identify savings opportunities.",
    "Finance literacy improves money decisions.",
    "Personal finance planning builds security.",
    "Budgeting helps track expenses.",
    "Investing grows wealth over time.",
    "Risk management protects financial goals.",
    "Education fosters lifelong learning.",
    "Quality education expands opportunity.",
    "Teachers adapt lessons to learners.",
    "Education technology enhances access.",
    "Critical thinking is taught in schools.",
    "Energy policy shapes market incentives.",
    "Solar power lowers peak demand.",
    "Wind energy diversifies resources.",
    "Energy conservation saves households money.",
    "Grid resilience improves reliability.",
    "Finance markets allocate capital efficiently.",
    "Interest rates influence borrowing.",
    "Credit management affects affordability.",
    "Financial regulation promotes stability.",
    "Savings habits support emergencies.",
    "Education equity reduces gaps.",
    "Curriculum design aligns with outcomes.",
    "Student assessment guides instruction.",
    "Professional development strengthens teaching.",
    "Lifelong education supports careers.",
    "Energy innovation drives competitiveness.",
    "Clean energy creates jobs.",
    "Electrification cuts pollution.",
    "Demand response balances loads.",
    "Energy data improves planning.",
    "Finance analytics inform strategy.",
    "Retirement planning ensures comfort.",
    "Taxes fund public services.",
    "Financial ethics build trust.",
    "Entrepreneurship fuels economies.",
    "Education research improves methods.",
    "Early education supports development.",
    "Higher education advances research.",
    "Vocational training builds skills.",
    "Digital literacy is essential.",
    "Energy efficiency standards save energy.",
    "Green finance funds sustainability.",
    "Financial inclusion broadens access.",
    "Education policy shapes systems.",
    "Community education strengthens society."
    "Energy transition requires careful planning and coordination.",
    "Renewable integration depends on effective storage solutions.",
    "Energy prices directly affect household budgets.",
    "Efficiency upgrades help reduce overall demand.",
    "Grid modernization boosts reliability and resilience.",
    "Finance education builds personal and community resilience.",
    "Cash flow management supports financial stability.",
    "Diversification reduces risk in investment portfolios.",
    "Long-term finance supports sustainable economic growth.",
    "Transparent accounting improves organizational trust.",
    "Education access expands opportunity for learners.",
    "Student engagement improves academic outcomes.",
    "Teacher training raises instructional quality.",
    "Curriculum updates reflect societal and technological change.",
    "Assessment data informs better learning strategies.",
    "Energy forecasting guides efficient operations.",
    "Clean fuels help reduce harmful emissions.",
    "Electrification supports decarbonization goals.",
    "Energy markets balance supply and demand.",
    "Conservation programs save natural resources.",
    "Finance technology streamlines modern payments.",
    "Credit scoring informs responsible lending decisions.",
    "Savings rates influence consumer behavior.",
    "Insurance helps manage financial uncertainty.",
    "Public finance funds essential infrastructure.",
    "Education leadership drives system-wide reform.",
    "Early literacy supports long-term success.",
    "STEM education fuels innovation.",
    "Career guidance aids student transitions.",
    "Lifelong learning helps adapt skills.",
    "Energy research accelerates innovation.",
    "Grid flexibility manages variable supply.",
    "Distributed energy empowers communities.",
    "Heat efficiency lowers household bills.",
    "Energy standards improve building performance.",
    "Finance governance ensures accountability.",
    "Ethical investing aligns money with values.",
    "Capital markets finance major projects.",
    "Inflation affects purchasing power.",
    "Financial planning helps set goals.",
    "Education equity narrows achievement gaps.",
    "Inclusive classrooms support diverse learners.",
    "Digital tools personalize education.",
    "Remote learning expands access.",
    "School partnerships enrich learning experiences.",
    "Energy data enables informed insights.",
    "Clean power improves public health.",
    "Finance collaboration drives economic growth.",
    "Education policy guides systems.",
    "Community learning builds social cohesion."
]
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# Download NLTK stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %% [markdown]
# ### Preprocess and tokenize

# %%
df_test = pd.DataFrame(corpus_list, columns = ['corpus col'])

# preprocess
def preprocess_text(text):
    text = re.sub('\s+', ' ', text)  # Remove extra spaces
    text = re.sub('\S*@\S*\s?', '', text)  # Remove emails
    text = re.sub('\'', '', text)  # Remove apostrophes
    text = re.sub('[^a-zA-Z]', ' ', text)  # Remove non-alphabet characters
    text = text.lower()  # Convert to lowercase
    return text

df_test['cleaned_text'] = df_test['corpus col'].apply(preprocess_text)

# %%
df_test.head()
# Out:
#                                        corpus col  \
# 0  Energy efficiency reduces costs and emissions.
# 1       Renewable energy supports a cleaner grid.
# 2         Energy storage stabilizes power supply.
# 3       Smart grids optimize energy distribution.
# 4   Energy audits identify savings opportunities.
#
#                                      cleaned_text
# 0  energy efficiency reduces costs and emissions
# 1       renewable energy supports a cleaner grid
# 2         energy storage stabilizes power supply
# 3       smart grids optimize energy distribution
# 4   energy audits identify savings opportunities

# %%
import gensim.corpora as corpora
def tokenize(text):
    tokens = gensim.utils.simple_preprocess(text, deacc=True)
    tokens = [token for token in tokens if token not in stop_words]
    return tokens

data = df_test
data['tokens'] = data['cleaned_text'].apply(tokenize)

# skip lemmatization temporarily until working through dependencies

# create dictionary and corpus

id2word = corpora.Dictionary(data['tokens'])

texts = data['tokens']

corpus = [id2word.doc2bow(text) for text in texts]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                            id2word=id2word,
                                            num_topics=3,
                                            random_state=100,
                                            update_every=1,
                                            chunksize=5,
                                            passes=10,
                                            alpha='auto',
                                            per_word_topics=True)

# %%
pyLDAvis.enable_notebook()

# %%
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)

# %%
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.156660 -0.035869       1        1  35.429987
# 2      0.111362 -0.109650       2        1  34.598672
# 0      0.045298  0.145519       3        1  29.971341, topic_info=                Term       Freq      Total Category  logprob  loglift
# 3             energy   9.000000   9.000000  Default  30.0000  30.0000
# 43         education  11.000000  11.000000  Default  29.0000  29.0000
# 22           finance   9.000000   9.000000  Default  28.0000  28.0000
# 45          learning   8.000000   8.000000  Default  27.0000  27.0000
# 9              power   5.000000   5.000000  Default  26.0000  26.0000
# ..               ...        ...        ...      ...      ...      ...
# 116  electrification   1.054129   1.477881   Topic3  -4.8822   0.8670
# 70         resources   0.991929   1.402331   Topic3  -4.9431   0.8587
# 233      flexibility   1.283441   1.878326   Topic3  -4.6854   0.8241
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# Save the plot as a self-contained HTML file.
pyLDAvis.save_html(vis, os.getcwd() +"/df_LDAvis.html")

# %% [markdown]
# ### Run examples with output

# %%
# save model to disk (no need to use pickle module)
lda_model.save('lda_test.model')

# %%
# load pretrained model for inference
lda_model_pretrained =  gensim.models.LdaModel.load('lda_test.model')

# %% [markdown]
# #### Inference

# %%
def preprocess_inference_data(inf_data, raw_col, tr_dictionary): 
    ###### convert to np.arrays for efficiency

    inf_data, inf_corpus_data, __corpus, __dictionary = lda.automate_corpus_prep(inference_data, 'raw_col')
    
    # create the bag of words using the training dictionary, not __dictionary built on inference data
    texts = list(inf_corpus_data['tokens'])
    inf_corpus = [tr_dictionary.doc2bow(text) for text in texts]
    print("corpus updated using training data dictionary rather than the inference data dictionary.")
    
    return(inf_corpus_data, inf_corpus)

# %%
inference_list = ['the state government passed a new policy restricting new coal plants for electricity and instead prioritize solar.', 
                 'the school was taught five subjects to children.']
inference_data = pd.DataFrame(inference_list, columns = ['raw_col'])

# %%
inf_corpus_data, inf_corpus = preprocess_inference_data(inference_data, 'raw_col', train_dictionary)

# %%
inf_corpus

# %% [markdown]
# ##### Run

# %%
inference_results = test_load_model[preprocessed]

# %%
inference_results = lda_model_pretrained[inf_corpus]
inference_results

# %% [markdown]
# ##### Examine raw gensim output with probabilities for each document / sentence

# %%
[p for p in inference_results]

# %%
topic_probs_document1 = inference_results[0][0]
topic_probs_document1

# %%
# model's pretrained topics and assigned weights for words
lda.topics_EDA(lda_model_pretrained, train_data, train_dictionary, ##### this should be corpus_data, but needs functionality to use df subset
                num_topics = 3, num_words = 10)

# %%
mapped_data_inference = lda.map_topics(lda_model_pretrained, inf_corpus_data, inference_results)
mapped_data_inference

# %%
mapped_data_inference['topic_title'].value_counts()

# %% [markdown]
# #### EDA on model itself

# %%
training_results = lda_model_pretrained[train_corpus]
print(len(training_results))
[p for p in training_results[0]]

# %%
mapped_data_training = lda.map_topics(lda_model_pretrained, train_corpus_data, training_results)

# %%
mapped_data_training['topic_title'].value_counts()
